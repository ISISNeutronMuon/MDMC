# %% [markdown]
# # Running a Simulation in MDMC
#
# This tutorial continues from the Building a Universe tutorial, using the example universe filled with SPCE water.

# %%
# %%capture
# Run Building a universe notebook and hide output
# %run "Building a Universe.ipynb"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-eb9a140db8ad> in <module>()
#       1 # Import the Universe class
# ----> 2 from MDMC.MD.simulation import Universe
#       3 # Initialise a Universe with dimensions in Ang
#       4 universe = Universe([10.0, 15.0, 20.0])
#
# ImportError: No module named MDMC.MD.simulation

# %% [markdown]
# ## Creating a Simulation object
# Simulations in MDMC are run using external MD engines (e.g. LAMMPS).  First create a universe (see [Building a Universe](https://github.com/MDMCproject/MDMCv0.2_pilot/wiki/Building-a-Universe) - an example universe can be found at the bottom of the page).  This universe object must then be passed when creating a Simulation object, along with simulation properties:

# %%
# Import the Simulation class
from MDMC.MD.simulation import Simulation

# Create an NPT simulation
simulation = Simulation(universe, engine='lammps', time_step=1., temperature=300.,
                        pressure=101325., traj_step=10, thermostat='nose',
                        barostat='nose', t_damp=100, p_damp=1000)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-27e19c9d7c79> in <module>()
#       1 # Import the Simulation class
# ----> 2 from MDMC.MD.simulation import Simulation
#       3
#       4 # Create an NPT simulation
#       5 simulation = Simulation(universe, engine='lammps', time_step=1., temperature=300.,
#
# ImportError: No module named MDMC.MD.simulation

# %% [markdown]
# The NPT simulation is created with a Nose-Hoover thermostat and a Berendsen barostat, with a temperature of 300 K, a pressure of 101325 Pa, and a time_step of 1.0 fs.  The trajectory is recorded every 10 simulation steps. The number of steps over which the temperature and pressure are damped for the thermostat and barostats is 100 and 1000 respectively.
#
# NVE and NVT simulations can be created in a similar manner by omitting one or both of the thermostat and barostat.  If both are omitted the temperature must still be specified as this initialises the atomic velocities.
#
# ## Energy minimisation and running a simulation
# The universe energy can be minimised by:

# %%
# Minimize the simulation for 10000 steps
simulation.minimize(10000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-203d60930809> in <module>()
#       1 # Minimize the simulation for 10000 steps
# ----> 2 simulation.minimize(10000)
#
# NameError: name 'simulation' is not defined

# %% [markdown]
# and the simulation can be equilibrated and run:

# %%
# Equilibrate the simulation for 10000 steps
# The trajectory is not stored during equilibration
simulation.run(10000, equilibration=True)
# Run the simulation for 50000 steps
simulation.run(50000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-13f0e6df18ec> in <module>()
#       1 # Equilibrate the simulation for 10000 steps
#       2 # The trajectory is not stored during equilibration
# ----> 3 simulation.run(10000, equilibration=True)
#       4 # Run the simulation for 50000 steps
#       5 simulation.run(50000)
#
# NameError: name 'simulation' is not defined

# %% [markdown]
# ## Trajectory
# An MDMC Trajectory object can be created following a simulation run using:

# %%
trajectory = simulation.trajectory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6ae6f38a9b98> in <module>()
# ----> 1 trajectory = simulation.trajectory
#
# NameError: name 'simulation' is not defined

# %% [markdown]
# ## Variation between MD engines
# In theory, all simulations on a MDMC Universe should be able to use any MD engine, although in practice this is limited by whether a particular MD engine supports a specific feature and if it has been implemented in the MD engine interface.  If a feature is not supported by or implemented for a specific MD engine, MDMC will raise a NotImplementedError.
